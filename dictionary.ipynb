# %% [markdown]
# <a href="https://colab.research.google.com/github/AnopaMunemo/Coding-Projects-/blob/main/dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
job_type_skills={'database':'postgresql','language':'python'}

# %%
job_type_skills
# Out:
# {'database': 'postgresql', 'language': 'python'}

# %%
job_type_skills.update({'cloud':'cloud coding'})

# %%
job_type_skills['cloud']
# Out:
# 'cloud coding'

# %%
job_type_skills['version_control']='git'

# %%
job_type_skills
# Out:
# {'database': 'postgresql',
#  'language': 'python',
#  'cloud': 'cloud coding',
#  'version_control': 'git'}
