# %% [markdown]
# <a href="https://colab.research.google.com/github/AnopaMunemo/Coding-Projects-/blob/main/loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#[] is needed to start a list so that it can later be appended

analyst_list = []

for job in job_list :
  if "Data Analyst" in job:
    analyst_list.append(job)

print(analyst_list)
# Out:
# ['Data Analyst']

# %%
numbers = [0,1,2,3,4,5]

for number in numbers:
  print(number)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
years_experience ={'Luke': 3,
                   'Kelly': 6,
                   'Ken': 4,
                   'Alex': 3,
                   'Mary': 7}

# %%
for key, value in years_experience.items():
  print(key,value)

  #items to get both name and value . Value to just get the value and to just get name just keep it as function name .
# Out:
# Luke 3
# Kelly 6
# Ken 4
# Alex 3

# %%
for key, value in years_experience.items():
  if value > 5 :
    print(key, 'has', value , 'years experience')
# Out:
# Kelly has 6 years experience

# %%
years_list = list(years_experience.items())

years =0
index = 0

while index <5 :
  key,value = years_list[index]
  if value >=5:
    print(key, 'has', value, 'years experience')
  years = value
  index +=1
# Out:
# Kelly has 6 years experience
# Mary has 7 years experience
